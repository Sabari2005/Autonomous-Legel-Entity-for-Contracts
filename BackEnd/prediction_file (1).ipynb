# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler, random_split
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
import nltk

import random
import time
import datetime
import shap

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yvarajan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("./Final_Full_Dataset.csv")

df = df.dropna(subset=["Risk Level"])

label_encoder_level = LabelEncoder()
label_encoder_category = LabelEncoder()

df['Risk Level'] = label_encoder_level.fit_transform(df['Risk Level'])
df['Risk Category'] = label_encoder_category.fit_transform(df['Risk Category'])


risk_level_mapping = {i: label for i, label in enumerate(label_encoder_level.classes_)}
risk_category_mapping = {i: label for i, label in enumerate(label_encoder_category.classes_)}

# %%
print("Risk Level Encodings:")
for encoded, original in risk_level_mapping.items():
    print(f"{original}: {encoded}")

print("\nRisk Category Encodings:")
for encoded, original in risk_category_mapping.items():
    print(f"{original}: {encoded}")
# Out:
# Risk Level Encodings:
# High: 0
# Low: 1
# Medium: 2
#
# Risk Category Encodings:
# Accelerated Payment Obligation: 0
# Acceptance: 1
# Acceptance Deadline: 2
# Acceptance Period: 3
# Acceptance Process: 4
# Acceptance and Returns: 5
# Access Control: 6
# Access Restrictions: 7
# Access Rights: 8
# Access to Business Records: 9
# Access to Financial Records: 10
# Access to Information: 11
# Access to Records: 12
# Accountability Obligation: 13
# Accounting: 14
# Accounting & Compliance: 15
# Acquisition & Ownership: 16
# Acquisition & Ownership Change: 17
# Acquisition Clause: 18
# Acquisition Restriction: 19
# Additional Charges: 20
# Additional Compliance Requirements: 21
# Additional Fees: 22
# Additional Financial Burden: 23
# Additional Insurance Requirement: 24
# Additional Insured: 25
# Additional Insured Coverage: 26
# Additional Insured Requirement: 27
# Additional Termination Fees: 28
# Administrative Burden: 29
# Administrative Compliance: 30
# Advance Notice: 31
# Advance Notice Obligation: 32
# Advance Notice Requirement: 33
# Advertisement Control: 34
# Advertising: 35
# Advertising & Competition: 36
# Advertising & Endorsement Rights: 37
# Advertising & Endorsements: 38
# Advertising & Market Restriction: 39
# Advertising & Marketing Restriction: 40
# Advertising & Performance Obligations: 41
# Advertising & Promotion: 42
# Advertising & Promotion Restrictions: 43
# Advertising Allocation Restriction: 44
# Advertising Commitment: 45
# Advertising Control: 46
# Advertising Duration Restriction: 47
# Advertising Fee: 48
# Advertising Flexibility: 49
# Advertising Liability: 50
# Advertising Limitations: 51
# Advertising Performance: 52
# Advertising Placement: 53
# Advertising Purchase Obligation: 54
# Advertising Removal: 55
# Advertising Restriction: 56
# Advertising Restrictions: 57
# Advertising Rights: 58
# Advertising Time Limitation: 59
# Advertising Time Requirement: 60
# Advertising, Event Publications: 61
# Advertising, Event Sponsorship: 62
# Advisor Affiliation: 63
# Affiliate Assignment: 64
# Affiliate Assignment Flexibility: 65
# Affiliate Competition: 66
# Affiliate Compliance: 67
# Affiliate Compliance Requirement: 68
# Affiliate Exception: 69
# Affiliate Exemption: 70
# Affiliate License Continuation: 71
# Affiliate Obligations: 72
# Affiliate Program: 73
# Affiliate Program Compliance: 74
# Affiliate Responsibilities: 75
# Affiliate Transfer: 76
# Affiliate-Specific Licensing: 77
# Agency Appointment: 78
# Aggregate Liability Cap: 79
# Aggregation of Claims: 80
# Agreement: 81
# Agreement Compliance: 82
# Agreement Duration: 83
# Agreement Duration Specification: 84
# Agreement Expiry Condition: 85
# Agreement Extension: 86
# Agreement Modification: 87
# Agreement Modifications: 88
# Agreement Term: 89
# Agreement Term & Renewal: 90
# Agreement Term and Duration: 91
# Agreement Termination: 92
# Agreement Validity: 93
# All-Encompassing IP Claim: 94
# Alternate Financing Rights: 95
# Alternative Payment Requirement: 96
# Alternative Product Royalty: 97
# Ambiguity: 98
# Ambiguity & Contractual Clarity: 99
# Ambiguity in Audit Access: 100
# Ambiguity in Compensation Terms: 101
# Ambiguity in Compliance: 102
# Ambiguity in Contract Duration: 103
# Ambiguity in Control Definition: 104
# Ambiguity in Coverage: 105
# Ambiguity in Default Conditions: 106
# Ambiguity in Definition: 107
# Ambiguity in Dispute Resolution: 108
# Ambiguity in Enforcement: 109
# Ambiguity in Financial Terms: 110
# Ambiguity in IP Assignment: 111
# Ambiguity in License Terms: 112
# Ambiguity in Party Definition: 113
# Ambiguity in Process: 114
# Ambiguity in Terms: 115
# Ambiguity in licensing terms: 116
# Ambiguous Compliance: 117
# Ambiguous Consent Criteria: 118
# Ambiguous Financial Definition: 119
# Ambiguous Financial Term: 120
# Ambiguous Liability Scope: 121
# Ambiguous Termination: 122
# Ambiguous Termination Condition: 123
# Amendment & Approval: 124
# Amendment Obligations: 125
# Amendment Requirement: 126
# Amendment Restrictions: 127
# Annual Audit: 128
# Anti-Collusion Clause: 129
# Anti-Competitive: 130
# Anti-Competitive & Restrictive Practices: 131
# Anti-Competitive Behavior: 132
# Anti-Competitive Practices: 133
# Anti-Competitive Restriction: 134
# Anti-Competitive Restrictions: 135
# Anti-Corruption Compliance: 136
# Anticipated Legal Action: 137
# Antitrust: 138
# Appearance Duration: 139
# Appearance Requirements: 140
# Application: 141
# Appointment Obligation: 142
# Appointment of Agent: 143
# Approval Dependencies: 144
# Approval Dependency: 145
# Approval Obligation: 146
# Approval Requirement: 147
# Approval Requirements: 148
# Approval Time Constraint: 149
# Approval and Control Over Licensing: 150
# Approval and Governance: 151
# Arbitrary Consent Denial: 152
# Arbitration: 153
# Arbitration & Dispute Resolution: 154
# Artwork and Production: 155
# Asset & Equipment: 156
# Asset Condition: 157
# Asset Control: 158
# Asset Destruction: 159
# Asset Disposal: 160
# Asset Disposal & Compliance: 161
# Asset Disposition: 162
# Asset Management: 163
# Asset Ownership: 164
# Asset Ownership & Transfers: 165
# Asset Ownership Restriction: 166
# Asset Purchase: 167
# Asset Purchase Rights: 168
# Asset Return Requirement: 169
# Asset Sale Restrictions: 170
# Asset Segmentation: 171
# Asset Transfer: 172
# Asset Transfer Restriction: 173
# Asset Transfer Rights: 174
# Assignee Financial Capacity: 175
# Assignee Production Capacity: 176
# Assignee Qualifications: 177
# Assignment: 178
# Assignment & Bankruptcy: 179
# Assignment & Change of Control: 180
# Assignment & Delegation: 181
# Assignment & Delegation Restriction: 182
# Assignment & Delegation Restrictions: 183
# Assignment & Termination: 184
# Assignment & Transfer: 185
# Assignment & Transfer Restriction: 186
# Assignment & Transfer Restrictions: 187
# Assignment & Transfer Rights: 188
# Assignment & Transferability: 189
# Assignment Approval Process: 190
# Assignment Assistance: 191
# Assignment Clause: 192
# Assignment Compliance: 193
# Assignment Condition: 194
# Assignment Conditions: 195
# Assignment Exception: 196
# Assignment Exceptions: 197
# Assignment Exemptions: 198
# Assignment Fairness: 199
# Assignment Flexibility: 200
# Assignment Limitations: 201
# Assignment Notice: 202
# Assignment Notice Requirement: 203
# Assignment Obligation: 204
# Assignment Restriction: 205
# Assignment Restrictions: 206
# Assignment Rights: 207
# Assignment Without Consent: 208
# Assignment and Change of Control: 209
# Assignment and Delegation Restriction: 210
# Assignment and Succession: 211
# Assignment and Transfer: 212
# Assignment and Transfer Exceptions: 213
# Assignment and Transfer Restriction: 214
# Assignment and Transfer Restrictions: 215
# Assignment and Transferability: 216
# Assignment in Case of Merger: 217
# Assignment of Obligations: 218
# Assignment of Rights: 219
# Assignment to Affiliates: 220
# Assignment/Transfer: 221
# Assistance Obligation: 222
# Assistance Requirement: 223
# Asymmetrical Termination Rights: 224
# At-Will Termination by Company: 225
# Attribution: 226
# Audit: 227
# Audit & Compliance: 228
# Audit & Compliance Obligation: 229
# Audit & Inspection: 230
# Audit & Record Retention: 231
# Audit & Record-Keeping: 232
# Audit Access: 233
# Audit Assistance: 234
# Audit Compliance: 235
# Audit Compliance Obligation: 236
# Audit Conditions: 237
# Audit Cost Allocation: 238
# Audit Cost Reimbursement: 239
# Audit Costs: 240
# Audit Frequency: 241
# Audit Frequency Limitation: 242
# Audit Frequency Restriction: 243
# Audit Frequency Restrictions: 244
# Audit Frequency and Scope: 245
# Audit Limitation: 246
# Audit Limitations: 247
# Audit Obligation: 248
# Audit Oversight & Compliance: 249
# Audit Procedure: 250
# Audit Process: 251
# Audit Process & Notice Requirement: 252
# Audit Process Restriction: 253
# Audit Reporting: 254
# Audit Requirement: 255
# Audit Responsibility: 256
# Audit Rights: 257
# Audit Rights and Frequency: 258
# Audit Scope: 259
# Audit Scope Limitation: 260
# Audit Timeline: 261
# Audit Timing: 262
# Audit Timing and Conditions: 263
# Audit Transparency: 264
# Audit Type: 265
# Audit Window: 266
# Audit and Compliance: 267
# Audit and Compliance Obligation: 268
# Audit and Compliance Rights: 269
# Audit and Inspection: 270
# Audit and Inspection Rights: 271
# Audit, Compliance: 272
# Audit, Monitoring: 273
# Audit-Based Financial Obligations: 274
# Auditing: 275
# Audits: 276
# Authentication: 277
# Authority & Representation: 278
# Authority Restriction: 279
# Auto Insurance: 280
# Auto Liability: 281
# Auto-Renewal: 282
# Auto-Renewal & Termination: 283
# Auto-Renewal Clause: 284
# Auto-Renewal Obligation: 285
# Auto-Renewal Obligations: 286
# Automatic Assignment: 287
# Automatic Assignment of Copyright: 288
# Automatic Contract Extension: 289
# Automatic Extension: 290
# Automatic Non-Renewal: 291
# Automatic Rejection: 292
# Automatic Renewal: 293
# Compound Classification: 744
# Compound Selection Rights: 745
# Comprehensive IP Control: 746
# Comprehensive IP Transfer: 747
# Comprehensive Rights Grant: 748
# Comprehensive Waiver: 749
# Comprehensive Waiver of Responsibility: 750
# Conditional Agreement: 751
# Conditional Assignment Rights: 752
# Conditional Call Option: 753
# Conditional Compliance: 754
# Conditional Cost Coverage: 755
# Conditional Escrow Release: 756
# Conditional IP Transfer: 757
# Conditional Indemnification: 758
# Conditional License Continuation: 759
# Conditional License Grant: 760
# Conditional Market Entry: 761
# Conditional Obligation: 762
# Conditional Revenue Obligation: 763
# Conditional Sublicensing: 764
# Conditional Sublicensing Rights: 765
# Conditional Termination Rights: 766
# Conditional Transfer: 767
# Conditional Use: 768
# Confidential Information: 769
# Confidential Information & Ownership: 770
# Confidential Information Retention: 771
# Confidential Information Usage: 772
# Confidential Information Use: 773
# Confidentiality: 774
# Confidentiality & Assignment: 775
# Confidentiality & Audit Access: 776
# Confidentiality & Competitive: 777
# Confidentiality & Compliance: 778
# Confidentiality & Data Protection: 779
# Confidentiality & Data Security: 780
# Confidentiality & Disclosure: 781
# Confidentiality & Documentation: 782
# Confidentiality & IP Protection: 783
# Confidentiality & Indemnification: 784
# Confidentiality & Liability: 785
# Confidentiality & Negligence: 786
# Confidentiality & Non-Compete: 787
# Confidentiality & Non-Disparagement: 788
# Confidentiality & Public Disclosure: 789
# Confidentiality & Security: 790
# Confidentiality & Use Restriction: 791
# Confidentiality Breach: 792
# Confidentiality Compliance: 793
# Confidentiality Concerns: 794
# Confidentiality Enforcement: 795
# Confidentiality Exceptions: 796
# Confidentiality Obligation: 797
# Confidentiality Obligations: 798
# Confidentiality Protection: 799
# Confidentiality Violation: 800
# Confidentiality and Compliance: 801
# Confidentiality and Data Access: 802
# Confidentiality and Indemnification: 803
# Confidentiality and Sublicensing: 804
# Confidentiality of Audit Findings: 805
# Confidentiality of Inspection Data: 806
# Configuration: 807
# Conflict Resolution: 808
# Conflict of Interest: 809
# Conflict of Interest Management: 810
# Conflict of Interest Restriction: 811
# Conflict of Interest in Legal Defense: 812
# Conflict of Law Exclusion: 813
# Conflict of Laws: 814
# Conflicts of Interest: 815
# Consent Denial: 816
# Consent Dependence: 817
# Consent Obligation: 818
# Consent Obligations: 819
# Consent Requirement: 820
# Consent Restriction: 821
# Consequential Damage Exclusion: 822
# Consequential Damage Waiver: 823
# Consequential Damages: 824
# Consequential Damages Disclaimer: 825
# Consequential Damages Exclusion: 826
# Consequential Damages Waiver: 827
# Construction: 828
# Construction Compliance: 829
# Construction Quality: 830
# Consultation Requirement: 831
# Consumer Lawsuit: 832
# Consumer Protecti: 833
# Consumer Protection: 834
# Consumer Protection Compliance: 835
# Consumer Protection Concerns: 836
# Consumer Protection and Liability: 837
# Consumer Rights: 838
# Consumer Rights Limitation: 839
# Consumer Safety: 840
# Content: 841
# Content Accuracy: 842
# Content Availability: 843
# Content Compliance: 844
# Content Control: 845
# Content Distribution: 846
# Content Distribution Restrictions: 847
# Content Distribution Rights: 848
# Contract Termination Obligations: 964
# Contract Timeline: 965
# Contract Transfer: 966
# Contract Transfer Fairness: 967
# Contract Transfer Restriction: 968
# Contract Transfer Restrictions: 969
# Contract Transferability: 970
# Contract Transition: 971
# Contract Uncertainty: 972
# Contract Validity: 973
# Contract Validity Date: 974
# Contract Validity Enforcement: 975
# Contract Violation: 976
# Contractor Indemnification: 977
# Contractor Relationship: 978
# Contractor's Confidential Information: 979
# Contractor's Pre-Existing IP: 980
# Contractual: 981
# Contractual & Compliance: 982
# Contractual Adjustment: 983
# Contractual Agreement: 984
# Contractual Ambiguity: 985
# Contractual Approval: 986
# Contractual Authority: 987
# Contractual Breach: 988
# Contractual Breach Liability: 989
# Contractual Broadcasting Restrictions: 990
# Contractual Carve-Outs: 991
# Contractual Changes: 992
# Contractual Clarity: 993
# Contractual Commitment: 994
# Contractual Communication Restriction: 995
# Contractual Completeness: 996
# Contractual Complexity: 997
# Contractual Complexity & Undefined Liabilities: 998
# Contractual Compliance: 999
# Contractual Condition: 1000
# Contractual Conditions: 1001
# Contractual Consent: 1002
# Contractual Consistency: 1003
# Contractual Contingency: 1004
# Contractual Continuity: 1005
# Contractual Control: 1006
# Contractual Control Limitation: 1007
# Contractual Deadline: 1008
# Contractual Definition: 1009
# Contractual Dependency: 1010
# Contractual Discretion: 1011
# Contractual Dispute: 1012
# Contractual Disputes: 1013
# Contractual Enforcement: 1014
# Contractual Exception: 1015
# Contractual Exception Ris: 1016
# Contractual Exceptions: 1017
# Contractual Exclusion: 1018
# Contractual Exclusivity: 1019
# Contractual Exit: 1020
# Contractual Exits: 1021
# Contractual Fairness: 1022
# Contractual Finality & Liability: 1023
# Contractual Financial: 1024
# Contractual Flexibility: 1025
# Contractual Gaps: 1026
# Contractual Hierarchy: 1027
# Contractual Imbalance: 1028
# Contractual Inflexibility: 1029
# Contractual Integrity: 1030
# Contractual Interference: 1031
# Contractual Interpretation: 1032
# Contractual Liability: 1033
# Contractual Limitation: 1034
# Contractual Limitations: 1035
# Contractual Lock-In: 1036
# Contractual Nature: 1037
# Contractual Negotiation: 1038
# Contractual Notice Requirement: 1039
# Contractual Obliga: 1040
# Contractual Obligation: 1041
# Contractual Obligations: 1042
# Contractual Obligations & Inventory Management: 1043
# Contractual Party Definition: 1044
# Contractual Payment Terms: 1045
# Contractual Performance Obligation: 1046
# Contractual Preferences: 1047
# Contractual Purchase Rights: 1048
# Contractual Reference: 1049
# Contractual Reliance: 1050
# Contractual Renewal: 1051
# Contractual Requirements: 1052
# Contractual Restriction: 1053
# Contractual Restrictions: 1054
# Contractual Rights: 1055
# Contractual Rights Expiry: 1056
# Contractual Rigidity: 1057
# Contractual Rigidness: 1058
# Contractual Sales Obligation: 1059
# Contractual Survival: 1060
# Contractual Termination: 1061
# Contractual Timeline & Execution: 1062
# Contractual Timeline Ambiguity: 1063
# Contractual Timing: 1064
# Contractual Uncertainty: 1065
# Contractual?: 1066
# Contribution Calculation: 1067
# Contribution Obligation: 1068
# Control: 1069
# Customer Poaching Restriction: 1177
# Customer Protection: 1178
# Customer Repair: 1179
# Customer Responsibility: 1180
# Customer Retention: 1181
# Customer Rights: 1182
# Customer Service: 1183
# Customer Sublicensing: 1184
# Customer Support: 1185
# Customer Support Obligation: 1186
# Customer Transition: 1187
# Customer Usage Rights: 1188
# Customization of Policy Trailer: 1189
# Cyber & Fraud Protection: 1190
# Cybersecurity: 1191
# Cybersecurity & Data Breach: 1192
# Cybersecurity?: 1193
# Damage Limitation: 1194
# Damages: 1195
# Damages Exclusion: 1196
# Damages Limitation: 1197
# Damages Waiver: 1198
# Data & Financial Losss: 1199
# Data & Intellectual Property: 1200
# Data & Intellectual Property Transfer: 1201
# Data & Material Disposal: 1202
# Data & Record Loss: 1203
# Data & Trade Secret: 1204
# Data Access: 1205
# Data Access & Audit: 1206
# Data Access & Confidentiality: 1207
# Data Access & Licensing: 1208
# Data Access & Privacy: 1209
# Data Access & Retention: 1210
# Data Access Control: 1211
# Data Access Obligation: 1212
# Data Access Obligation for Third-Party Contracts: 1213
# Data Access Requirement: 1214
# Data Access Restriction: 1215
# Data Access and Confidentiality: 1216
# Data Access and Privacy: 1217
# Data Accuracy: 1218
# Data Accuracy and Reliability: 1219
# Data Aggregation: 1220
# Data Commercialization: 1221
# Data Confidentiality: 1222
# Data Control: 1223
# Data Control & Compliance: 1224
# Data Control & Confidentiality: 1225
# Data Control and Usage: 1226
# Data Costs: 1227
# Data Deletion Requirement: 1228
# Data Disclosure & Audit: 1229
# Data Disclosure Obligation: 1230
# Data Handling: 1231
# Data Handling Rights: 1232
# Data Integrity: 1233
# Data Loss Exclusion: 1234
# Data Loss Limitation: 1235
# Data Management: 1236
# Data Misuse: 1237
# Data Ownership: 1238
# Data Ownership & Control: 1239
# Data Ownership & Licensing: 1240
# Data Ownership & Privacy: 1241
# Data Privacy: 1242
# Data Privacy & Audit Compliance: 1243
# Data Privacy & Compliance: 1244
# Data Privacy & Confidentiality: 1245
# Data Privacy & Licensing: 1246
# Data Privacy & Ownership: 1247
# Data Privacy & Usage Restriction: 1248
# Data Privacy and Compliance: 1249
# Data Privacy and Confidentiality: 1250
# Data Privacy and Non-Solicitation: 1251
# Data Protection: 1252
# Data Protection & Backup Responsibility: 1253
# Data Protection & Non-Solicitation: 1254
# Data Protection Compliance: 1255
# Data Protection Liability: 1256
# Data Provision: 1257
# Data Purchase Obligation: 1258
# Data Reliability: 1259
# Data Restriction / Post-Term Obligation: 1260
# Data Restrictions: 1261
# Data Retention: 1262
# Data Retention & Compliance: 1263
# Data Retention & Post-Termination Rights: 1264
# Data Retention Restriction: 1265
# Data Rights and Licensing: 1266
# Data Security: 1267
# Data Security & Access: 1268
# Data Security & Compliance: 1269
# Data Security & Confidentiality: 1270
# Data Security & Liability: 1271
# Data Security & Remote Access: 1272
# Data Security?: 1273
# Data Sensitivity & Control: 1274
# Data Sharing: 1275
# Data Sharing & Licensing: 1276
# Data Sharing & Regulatory Compliance: 1277
# Data Sharing Obligation: 1278
# Data Sharing Requirement: 1279
# Data Sharing Restrictions: 1280
# Data Storage: 1281
# Data Storage Compliance: 1282
# Data Transfer: 1283
# Data Transfer Obligation: 1284
# Data Transparency: 1285
# Data Usage: 1286
# Data Usage & Privacy: 1287
# Data Usage Restriction: 1288
# Data Usage Restrictions: 1289
# Data Usage Rights: 1290
# Data Use Restrictions: 1291
# Data and Information Rights: 1292
# Data and Process Access: 1293
# Decision Delay: 1294
# Decision Timeline Obligation: 1295
# Decision Timeliness: 1296
# Decision-Making Timeframe: 1297
# Dedicated Resource Obligation: 1298
# Deemed Waiver of Rights: 1299
# Defamation and IP: 1300
# Default & Bankruptcy Clause: 1301
# Default Condition Restriction: 1302
# Default and Cure Rights: 1303
# Default/Termination: 1304
# Defect Resolution: 1305
# Defective Product: 1306
# Defense Control: 1307
# Defense Cost Coverage: 1308
# Defense Obligation: 1309
# Defense Obligations: 1310
# Defense Responsibility: 1311
# Defense Rights: 1312
# Defense and Settlement Rights: 1313
# Defined Contact Limitation: 1314
# Defined Duration: 1315
# Defined Effective Date: 1316
# Defined Timeline: 1317
# Definition & Interpretation: 1318
# Definition Ambiguity: 1319
# Definition Clause: 1320
# Definition of Content Provider: 1321
# Definition of Entity: 1322
# Definition of Parties: 1323
# Definitions: 1324
# Delay Charges: 1325
# Delay Management: 1326
# Delay in Ownership Transfer: 1327
# Delayed Consent: 1328
# Delayed Financial Liabilities: 1329
# Delayed Termination: 1330
# Delegation Restriction: 1331
# Delegation Rights: 1332
# Delivery: 1333
# Delivery Compliance: 1334
# Delivery Constraints: 1335
# Delivery Location Clarity: 1336
# Delivery Obligation: 1337
# Delivery Schedule: 1338
# Demonstration License: 1339
# Dependency on Master Agreement: 1340
# Dependency on Other Clauses: 1341
# Dependency on Third-Party Agreements: 1342
# Dependency on Third-Party Licensing: 1343
# Dependent Expiry Condition: 1344
# Deployment Limitation: 1345
# Depreciation: 1346
# Derivative Work Restriction: 1347
# Derivative Works Usage: 1348
# Derivative Works and Copy Protection: 1349
# Development: 1350
# Development Delays: 1351
# Development Freeze: 1352
# Development Licensing: 1353
# Development Obligation: 1354
# Development Obligations: 1355
# Development Ownership: 1356
# Development Process: 1357
# Development Rights: 1358
# Development and Commercialization Rights: 1359
# Development-Related Data Usage: 1360
# Digital Asset Control: 1361
# Digital Carousel Advertising: 1362
# Digital Contract Execution: 1363
# Digital Linking: 1364
# Digital Media Usage: 1365
# Digital Rights: 1366
# Digital Sales Model: 1367
# Digital Usage Rights: 1368
# Dilution: 1369
# Disclaimer of Confidential Information Accuracy: 1370
# Disclaimer of Liability: 1371
# Disclaimer of Warranties: 1372
# Disclaimer of Warranty: 1373
# Disclaimers: 1374
# Disclosure: 1375
# Disclosure & Identification: 1376
# Disclosure & Information: 1377
# Disclosure & Timing: 1378
# Disclosure Accuracy: 1379
# Disclosure Obligation: 1380
# Disclosure Obligations: 1381
# Disclosure Requirements: 1382
# Discount Limitations: 1383
# Discretionary Obligation: 1384
# Discretionary Registration Rights: 1385
# Discretionary Rights: 1386
# Disposition Timing: 1387
# Dispute: 1388
# Dispute & Compensation: 1389
# Dispute Handling Ambiguity Ri: 1390
# Dispute Resoluti: 1391
# Dispute Resolutio: 1392
# Dispute Resolution: 1393
# Dispute Resolution Ambiguity: 1394
# Distribution: 1395
# Distribution & Sales: 1396
# Distribution Agreement: 1397
# Distribution Control: 1398
# Distribution Limitation: 1399
# Distribution Method Restrictions: 1400
# Distribution Obligation: 1401
# Distribution Restriction: 1402
# Distribution Restrictions: 1403
# Distribution Rights: 1404
# Distributor Indemnification: 1405
# Distributor Liability: 1406
# Diverging Legal Interests: 1407
# Divestiture Notification Obligation: 1408
# Document Transfer: 1409
# Documentation: 1410
# Documentation & Assignment: 1411
# Documentation & Compliance: 1412
# Documentation Access: 1413
# Documentation Accuracy: 1414
# Documentation Compliance: 1415
# Documentation Compliance Ris: 1416
# Documentation Obligation: 1417
# Documentation Requirement: 1418
# Documentation Requirements: 1419
# Documentation and Compliance: 1420
# Domain Licensing: 1421
# Domain Name Reassignment: 1422
# Domain Name Restriction: 1423
# Domain Name Transfer: 1424
# Domain Name Usage: 1425
# Downtime Limitations: 1426
# Due Diligence: 1427
# Duration Ambiguity: 1428
# Duration Limitation: 1429
# Duration Overreach: 1430
# Duration of Agreement: 1431
# Duration of Transition Obligations: 1432
# E-Commerce Limitation: 1433
# Early Renewal Requirement: 1434
# Early Termination: 1435
# Early Termination Clause: 1436
# Early Termination Condition: 1437
# Early Termination Cost: 1438
# Economic Loss: 1439
# Effective Date Clarification: 1440
# Effective Date of Termination: 1441
# Employee: 1442
# Employee Benefits: 1443
# Employee Compensation: 1444
# Employee Coverage: 1445
# Employee Fraud: 1446
# Employee IP Assignment Compliance: 1447
# Employee Liability: 1448
# Employee Liability Exclusion: 1449
# Employee Misclassification: 1450
# Employee Misconduct: 1451
# Employee Mobility Restriction: 1452
# Employee Non-Solicitation: 1453
# Employee Oversight: 1454
# Employee Poaching: 1455
# Employee Poaching & Compensation: 1456
# Employee Poaching Restriction: 1457
# Employee Protection: 1458
# Employee Redundancy: 1459
# Employee Relations: 1460
# Employee Retention: 1461
# Employee Retention Obligation: 1462
# Employee Rights: 1463
# Employee Rights Violation: 1464
# Employee Safety & Compliance: 1465
# Employee Solicitation: 1466
# Employee Solicitation & Non-Solicitation: 1467
# Employee and Customer Interaction: 1468
# Employee-Initiated Contact: 1469
# Employer Discretion: 1470
# Employer Liability: 1471
# Employment: 1472
# Employment & Benefits: 1473
# Employment & Competition Restriction: 1474
# Employment & Competitive: 1475
# Employment & IP: 1476
# Employment & Termination: 1477
# Employment Classification: 1478
# Employment Liabilities: 1479
# Employment Liability: 1480
# Employment Restriction: 1481
# Employment Restriction Exception: 1482
# Employment Restrictions: 1483
# Employment Rights: 1484
# Employment Rights Waiver: 1485
# Employment Solicitation Loophole: 1486
# Employment Termination: 1487
# Employment Terms: 1488
# Employment and Contractual: 1489
# Employment and Legal Liability: 1490
# Employment/IP Conflict: 1491
    punctuations = '@#!?+&*[]-%.:/();$=><|{}^' + "'`" + '_'
    for p in punctuations:
        text = text.replace(p, '')
    sw = stopwords.words('english')
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    text = " ".join(text)
    return text

# %%
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True, model_max_length=512)

# %%
class BertForMultiTaskClassification(BertForSequenceClassification):
    def __init__(self, config, num_labels_level, num_labels_category):
        super().__init__(config)
        self.num_labels_level = num_labels_level
        self.num_labels_category = num_labels_category
        self.classifier_level = torch.nn.Linear(config.hidden_size, num_labels_level)
        self.classifier_category = torch.nn.Linear(config.hidden_size, num_labels_category)

    def forward(self, input_ids, attention_mask=None, labels_level=None, labels_category=None):
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        pooled_output = outputs[1]

        logits_level = self.classifier_level(pooled_output)
        logits_category = self.classifier_category(pooled_output)

        loss = None
        if labels_level is not None and labels_category is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            loss_level = loss_fct(logits_level.view(-1, self.num_labels_level), labels_level.view(-1))
            loss_category = loss_fct(logits_category.view(-1, self.num_labels_category), labels_category.view(-1))
            loss = loss_level + loss_category

        return {
            "logits_level": logits_level,
            "logits_category": logits_category,
            "loss": loss
        }

# %%
model = BertForMultiTaskClassification.from_pretrained(
    "bert-large-uncased",
    num_labels_level=len(label_encoder_level.classes_),
    num_labels_category=len(label_encoder_category.classes_)
)
# Out:
# Some weights of BertForMultiTaskClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'classifier_category.bias', 'classifier_category.weight', 'classifier_level.bias', 'classifier_level.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
model.load_state_dict(torch.load('Risk_analysis_BERT.pth',map_location=torch.device('cpu')))
model.eval() 
print("Model loaded successfully.")
# Out:
# C:\Users\yvarajan\AppData\Local\Temp\ipykernel_19876\1012877533.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('Risk_analysis_BERT.pth',map_location=torch.device('cpu')))
# Model loaded successfully.

# %%
def predict_risk(text):
    cleaned_text = clean_text(text)
    encoded_dict = tokenizer.encode_plus(
        cleaned_text, 
        add_special_tokens=True,
        max_length=512,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )
    input_ids = encoded_dict['input_ids'].to(device)
    attention_mask = encoded_dict['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
  
    predicted_level = np.argmax(outputs["logits_level"].cpu().numpy(), axis=1).flatten()[0]
    predicted_category = np.argmax(outputs["logits_category"].cpu().numpy(), axis=1).flatten()[0]

    return (
        risk_level_mapping.get(predicted_level, "Unknown"),
        risk_category_mapping.get(predicted_category, "Unknown")
    )

def predict(texts):
    if isinstance(texts, str):
        texts = [texts]
    elif isinstance(texts, np.ndarray):
        texts = list(texts)

    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True, max_length=512)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    with torch.no_grad():
        logits_level = model(input_ids, attention_mask=attention_mask)["logits_level"]
    
    return torch.softmax(logits_level, dim=-1).cpu().numpy()

# %%
input_text = input("Enter text: ")
risk_level, risk_category = predict_risk(input_text)
print(f"\nPredicted Risk Level: {risk_level}")
print(f"Predicted Risk Category: {risk_category}")

explainer = shap.Explainer(predict, tokenizer)
shap_values = explainer([input_text])
shap.plots.text(shap_values)

# %%
import torch
from transformers import BertTokenizer
import numpy as np
import shap


tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)

def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  

    
    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts

def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []


    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:

        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)

    return risk_levels, risk_categories, shap_values_list


def display_results(chunks, risk_levels, risk_categories, shap_values_list):
    print("\nResults for Each Chunk:")
    for i, (chunk, risk_level, risk_category) in enumerate(zip(chunks, risk_levels, risk_categories)):
        print(f"\nChunk {i + 1}:")
        print(f"Text: {chunk}")
        print(f"Predicted Risk Level: {risk_level}")
        print(f"Predicted Risk Category: {risk_category}")
        print("SHAP Text Plot:")
        shap.plots.text(shap_values_list[i])

input_document = input("Enter the full document text: ")
if input_document.strip():
    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)
    risk_levels, risk_categories, shap_values_list = predict_risk_for_chunks(chunks)

    display_results(chunks, risk_levels, risk_categories, shap_values_list)
else:
    print("Input text cannot be empty. Please try again.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:50, 50.28s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.37s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.42s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.39s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.77s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.59s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.47s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.96s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.84s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.65s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.46s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:45, 45.11s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:41, 41.10s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]

# %%
import torch
from transformers import BertTokenizer
import numpy as np
import shap

# Check if GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)

# Function to split a document into overlapping chunks
def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  # Move start by (max_length - overlap)

    # Convert chunks back to text
    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts

# Function to predict risk level and category for each chunk
def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []

    # Initialize SHAP explainer
    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:
        # Predict risk level and category
        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        # Generate SHAP values for the chunk
        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)

    return risk_levels, risk_categories, shap_values_list

# Function to combine and display results
def display_results(chunks, risk_levels, risk_categories, shap_values_list):
    print("\nResults for Each Chunk:")
    for i, (chunk, risk_level, risk_category) in enumerate(zip(chunks, risk_levels, risk_categories)):
        print(f"\nChunk {i + 1}:")
        print(f"Text: {chunk}")
        print(f"Predicted Risk Level: {risk_level}")
        print(f"Predicted Risk Category: {risk_category}")
        print("SHAP Text Plot:")
        shap.plots.text(shap_values_list[i])

# Example usage
input_document = input("Enter the full document text: ")
if input_document.strip():
    # Split the document into overlapping chunks
    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)

    # Predict risk level and category for each chunk
    risk_levels, risk_categories, shap_values_list = predict_risk_for_chunks(chunks)

    # Display results for each chunk
    display_results(chunks, risk_levels, risk_categories, shap_values_list)
else:
    print("Input text cannot be empty. Please try again.")

# %% [markdown]
# # first html file with risk output with chunck

# %%
import torch
from transformers import BertTokenizer
import numpy as np
import shap
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet

# Check if GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)

# Function to split a document into overlapping chunks
def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  # Move start by (max_length - overlap)

    # Convert chunks back to text
    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts

# Function to predict risk level and category for each chunk
def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []

    # Initialize SHAP explainer
    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:
        # Predict risk level and category
        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        # Generate SHAP values for the chunk
        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)

    return risk_levels, risk_categories, shap_values_list

# Function to save results as a single HTML file
def save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="output.html"):
    html_content = """
    <html>
    <head>
        <title>Legal Risk Analysis Report</title>
        <style>
            body { font-family: Arial, sans-serif; }
            h1 { color: #2c3e50; }
            h2 { color: #34495e; }
            h3 { color: #7f8c8d; }
            iframe { border: 1px solid #ddd; margin-bottom: 20px; }
        </style>
    </head>
    <body>
        <h1>Legal Risk Analysis Report</h1>
    """

    for i, (chunk, risk_level, risk_category) in enumerate(zip(chunks, risk_levels, risk_categories)):
        html_content += f"<p><strong>Predicted Risk Level:</strong> {risk_level}</p>"
        html_content += f"<p><strong>Predicted Risk Category:</strong> {risk_category}</p>"

        # Generate SHAP plot as HTML and embed it directly
        shap_html = shap.plots.text(shap_values_list[i], display=False) 
        html_content += shap_html

    html_content += """
    </body>
    </html>
    """

    with open(filename, "w", encoding="utf-8") as f:
        f.write(html_content)
    print(f"Results saved to {filename}")

# Example usage
input_document = input("Enter the full document text: ")
if input_document.strip():
    # Split the document into overlapping chunks
    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)

    # Predict risk level and category for each chunk
    risk_levels, risk_categories, shap_values_list = predict_risk_for_chunks(chunks)

    # Save results as a single HTML file
    save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="legal_risk_analysis_report.html")
else:
    print("Input text cannot be empty. Please try again.")

# %%
# %pip install groq

# %%
from groq import Groq

# %%
groq_API_KEY  = "YOUR API KEY"
client =Groq(api_key=groq_API_KEY)

# %% [markdown]
# # risk html with sugession for high riisk alone

# %%
import torch
from transformers import BertTokenizer
import numpy as np
import shap

# Check if GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)

# Function to split a document into overlapping chunks
def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  # Move start by (max_length - overlap)

    # Convert chunks back to text
    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts

# Function to predict risk level and category for each chunk
def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []

    # Initialize SHAP explainer
    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:
        # Predict risk level and category
        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        # Generate SHAP values for the chunk
        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)

    return risk_levels, risk_categories, shap_values_list

# Function to modify high-risk text
def modifier_model(text, risk_level, risk_category):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"""
                You are a legal risk mitigation expert. Your task is to modify the given contract text by removing or rewording high-risk clauses alone while making them favorable for the company side alone. and dont change remaing text\n
                Risk Level :\n {risk_level}\n
                Risk category :\n {risk_category}\n

                Modify the following text accordingly:
                {text}
                
                Provide only final text with modification and exclude explanation
                """
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content.strip()

# Function to save results as a single HTML file
def save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="output.html"):
    html_content = """
    <html>
    <head>
        <title>Legal Risk Analysis Report</title>
        <style>
            body { font-family: Arial, sans-serif; }
            h1 { color: #2c3e50; }
            h2 { color: #34495e; }
            h3 { color: #7f8c8d; }
            .suggestion { background-color: #f9f9f9; padding: 10px; border-left: 4px solid #ccc; margin-top: 10px; }
            .modified-text { background-color: #e8f5e9; padding: 10px; border-left: 4px solid #4caf50; margin-top: 10px; }
        </style>
    </head>
    <body>
        <h1>Legal Risk Analysis Report</h1>
    """

    for i, (chunk, risk_level, risk_category) in enumerate(zip(chunks, risk_levels, risk_categories)):
        html_content += f"<h2>Chunk {i + 1}</h2>"
        html_content += f"<p><strong>Text:</strong> {chunk}</p>"
        html_content += f"<p><strong>Predicted Risk Level:</strong> {risk_level}</p>"
        html_content += f"<p><strong>Predicted Risk Category:</strong> {risk_category}</p>"

        # Generate SHAP plot as HTML and embed it directly
        shap_html = shap.plots.text(shap_values_list[i], display=False)
        html_content += "<h3>SHAP Text Plot</h3>"
        html_content += shap_html

        # Provide suggestions and modified text for high-risk chunks
        if risk_level == "High":
            suggestion = "This text is identified as high-risk. Consider modifying the following clauses:"
            modified_text = modifier_model(chunk, risk_level, risk_category)

            html_content += f"<div class='suggestion'><strong>Suggestion:</strong> {suggestion}</div>"
            html_content += f"<div class='modified-text'><strong>Modified Text:</strong> {modified_text}</div>"

    html_content += """
    </body>
    </html>
    """

    with open(filename, "w", encoding="utf-8") as f:
        f.write(html_content)
    print(f"Results saved to {filename}")

# Example usage
input_document = input("Enter the full document text: ")
if input_document.strip():
    # Split the document into overlapping chunks
    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)

    # Predict risk level and category for each chunk
    risk_levels, risk_categories, shap_values_list = predict_risk_for_chunks(chunks)

    # Save results as a single HTML file
    save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="legal_risk_analysis_report.html")
else:
    print("Input text cannot be empty. Please try again.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:49, 49.47s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.52s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.75s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.87s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.03s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.88s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.86s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.89s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:43, 43.80s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:32, 32.22s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# Results saved to legal_risk_analysis_report.html

# %%
import torch
from transformers import BertTokenizer
import numpy as np
import shap

# Check if GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)

# Function to split a document into overlapping chunks
def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  # Move start by (max_length - overlap)

    # Convert chunks back to text
    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts

# Function to predict risk level and category for each chunk
def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []

    # Initialize SHAP explainer
    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:
        # Predict risk level and category
        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        # Generate SHAP values for the chunk
        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)

    return risk_levels, risk_categories, shap_values_list

# Function to modify high or medium-risk text
#You are a legal risk mitigation expert. Your task is to modify the given contract text by removing or rewording high or medium-risk clauses alone while making them favorable for the company side alone. and dont change remaing text\n

def modifier_model(text, risk_level, risk_category):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"""
                You are a legal risk mitigation expert. Your task is to modify the given contract text by removing or rewording high or medium-risk clauses alone while making them balanced for both side. and dont change remaing text\n
                Risk Level :\n {risk_level}\n
                Risk category :\n {risk_category}\n

                Modify the following text accordingly:
                {text}
                
                Provide only final text with modification and exclude explanation
                """
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content.strip()

# Function to save results as a single HTML file
def save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="output.html"):
    html_content = """
    <html>
    <head>
        <title>Legal Risk Analysis Report</title>
        <style>
            body { font-family: Arial, sans-serif; }
            h1 { color: #2c3e50; }
            h2 { color: #34495e; }
            h3 { color: #7f8c8d; }
            .suggestion { background-color: #f9f9f9; padding: 10px; border-left: 4px solid #ccc; margin-top: 10px; }
            .modified-text { background-color: #e8f5e9; padding: 10px; border-left: 4px solid #4caf50; margin-top: 10px; }
            .original-text { background-color: #fff3e0; padding: 10px; border-left: 4px solid #ffa726; margin-top: 10px; }
            .full-document { background-color: #e3f2fd; padding: 10px; border-left: 4px solid #42a5f5; margin-top: 20px; }
        </style>
    </head>
    <body>
        <h1>Legal Risk Analysis Report</h1>
    """

    full_document_original = []
    full_document_modified = []

    for i, (chunk, risk_level, risk_category) in enumerate(zip(chunks, risk_levels, risk_categories)):
        html_content += f"<h2>Chunk {i + 1}</h2>"
        html_content += f"<p><strong>Text:</strong> {chunk}</p>"
        html_content += f"<p><strong>Predicted Risk Level:</strong> {risk_level}</p>"
        html_content += f"<p><strong>Predicted Risk Category:</strong> {risk_category}</p>"

        # Generate SHAP plot as HTML and embed it directly
        shap_html = shap.plots.text(shap_values_list[i], display=False)
        html_content += "<h3>SHAP Text Plot</h3>"
        html_content += shap_html

        # Provide suggestions and modified text for high or medium-risk chunks
        if risk_level in ["High", "Medium"]:
            suggestion = f"This text is identified as {risk_level.lower()}-risk. Consider modifying the following clauses:"
            modified_text = modifier_model(chunk, risk_level, risk_category)

            html_content += f"<div class='suggestion'><strong>Suggestion:</strong> {suggestion}</div>"
            html_content += f"<div class='modified-text'><strong>Modified Text:</strong> {modified_text}</div>"
        else:
            modified_text = chunk  # No modification for low-risk chunks

        # Append to full document text
        full_document_original.append(chunk)
        full_document_modified.append(modified_text)

    # Combine full document text
    full_document_original = " ".join(full_document_original)
    full_document_modified = " ".join(full_document_modified)

    # Add full document text to the HTML report
    html_content += "<h2>Full Document Text</h2>"
    html_content += "<div class='full-document'>"
    html_content += "<h3>Original Text</h3>"
    html_content += f"<div class='original-text'>{full_document_original}</div>"
    html_content += "<h3>Modified Text</h3>"
    html_content += f"<div class='modified-text'>{full_document_modified}</div>"
    html_content += "</div>"

    html_content += """
    </body>
    </html>
    """

    with open(filename, "w", encoding="utf-8") as f:
        f.write(html_content)
    print(f"Results saved to {filename}")

# Example usage
input_document = input("Enter the full document text: ")
if input_document.strip():
    # Split the document into overlapping chunks
    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)

    # Predict risk level and category for each chunk
    risk_levels, risk_categories, shap_values_list = predict_risk_for_chunks(chunks)

    # Save results as a single HTML file
    save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, filename="legal_risk_analysis_report.html")
else:
    print("Input text cannot be empty. Please try again.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.14s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.37s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.42s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.45s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:44, 44.50s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:26, 26.46s/it]
# Results saved to legal_risk_analysis_report.html

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


tokenizer = BertTokenizer.from_pretrained('bert-large-uncased', do_lower_case=True)


def split_into_overlapping_chunks(text, max_length=512, overlap=256):
    tokens = tokenizer.tokenize(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = start + max_length
        chunk = tokens[start:end]
        chunks.append(chunk)
        start += (max_length - overlap)  


    chunk_texts = [tokenizer.convert_tokens_to_string(chunk) for chunk in chunks]
    return chunk_texts


def predict_risk_for_chunks(chunks):
    risk_levels = []
    risk_categories = []
    shap_values_list = []
    explanations = []


    explainer = shap.Explainer(predict, tokenizer)

    for chunk in chunks:
     
        risk_level, risk_category = predict_risk(chunk)
        risk_levels.append(risk_level)
        risk_categories.append(risk_category)

        shap_values = explainer([chunk])
        shap_values_list.append(shap_values)
        
        explanation = explain_chunk(chunk, risk_level, risk_category)
        explanations.append(explanation)

    return risk_levels, risk_categories, shap_values_list, explanations


def explain_chunk(chunk, risk_level, risk_category):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"""
                You are a legal risk expert. Analyze the following contract text chunk and provide a detailed explanation of:
                1. Why this text was classified as {risk_level} risk
                2. The specific clauses or phrases that contributed to this risk level
                3. The implications of this risk category ({risk_category})
                
                Provide this in clear, concise bullet points.
                
                Text chunk:
                {chunk}

                Exclude explanation
                """
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content.strip()


def modifier_model(text, risk_level, risk_category):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"""
                You are a legal risk mitigation expert. Your task is to modify the given contract text by removing or rewording high or medium-risk clauses alone while making them balanced for both side. and dont change remaing text\n
                Risk Level :\n {risk_level}\n
                Risk category :\n {risk_category}\n

                Modify the following text accordingly:
                {text}
                
                Provide only final text with modification and exclude explanation
                """
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content.strip()

def save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, explanations, filename="output.html"):
    html_content = """
    <html>
    <head>
        <title>Legal Risk Analysis Report</title>
        <style>
            body { font-family: Arial, sans-serif; }
            h1 { color: #2c3e50; }
            h2 { color: #34495e; }
            h3 { color: #7f8c8d; }
            .explanation { background-color: #f0f7ff; padding: 10px; border-left: 4px solid #3498db; margin-top: 10px; }
            .modified-text { background-color: #e8f5e9; padding: 10px; border-left: 4px solid #4caf50; margin-top: 10px; }
            .original-text { background-color: #fff3e0; padding: 10px; border-left: 4px solid #ffa726; margin-top: 10px; }
            .full-document { background-color: #e3f2fd; padding: 10px; border-left: 4px solid #42a5f5; margin-top: 20px; }
            .risk-high { color: #e74c3c; font-weight: bold; }
            .risk-medium { color: #f39c12; font-weight: bold; }
            .risk-low { color: #2ecc71; font-weight: bold; }
        </style>
    </head>
    <body>
        <h1>Legal Risk Analysis Report</h1>
    """

    full_document_original = []
    full_document_modified = []

    for i, (chunk, risk_level, risk_category, explanation) in enumerate(zip(chunks, risk_levels, risk_categories, explanations)):

        risk_class = f"risk-{risk_level.lower()}"
        
        html_content += f"<h2>Chunk {i + 1}</h2>"
        html_content += f"<div class='original-text'><strong>Original Text:</strong> {chunk}</div>"
        html_content += f"<p><strong>Predicted Risk Level:</strong> <span class='{risk_class}'>{risk_level}</span></p>"
        html_content += f"<p><strong>Predicted Risk Category:</strong> {risk_category}</p>"
        

        html_content += "<h3>Risk Explanation</h3>"
        html_content += f"<div class='explanation'>{explanation}</div>"


        shap_html = shap.plots.text(shap_values_list[i], display=False)
        html_content += "<h3>SHAP Text Plot</h3>"
        html_content += shap_html


        if risk_level in ["High", "Medium", "Low"]:
            modified_text = modifier_model(chunk, risk_level, risk_category)
        else:
            modified_text = chunk  

        full_document_original.append(chunk)
        full_document_modified.append(modified_text)


    full_document_original = " ".join(full_document_original)
    full_document_modified = " ".join(full_document_modified)

    html_content += "<h2>Full Document Text</h2>"
    html_content += "<div class='full-document'>"
    html_content += "<h3>Original Text</h3>"
    html_content += f"<div class='original-text'>{full_document_original}</div>"
    html_content += "<h3>Modified Text</h3>"
    html_content += f"<div class='modified-text'>{full_document_modified}</div>"
    html_content += "</div>"

    html_content += """
    </body>
    </html>
    """

    with open(filename, "w", encoding="utf-8") as f:
        f.write(html_content)
    print(f"Results saved to {filename}")


input_document = input("Enter the full document text: ")
if input_document.strip():

    chunks = split_into_overlapping_chunks(input_document, max_length=512, overlap=256)


    risk_levels, risk_categories, shap_values_list, explanations = predict_risk_for_chunks(chunks)

    save_results_as_html(chunks, risk_levels, risk_categories, shap_values_list, explanations, filename="legal_risk_analysis_report.html")
else:
    print("Input text cannot be empty. Please try again.")

# %%
import requests

url = " https://1774-34-87-10-141.ngrok-free.app/upload"
files = {"file": open("E:/projects/Unisys_Dev/Trying/BackEnd/uploaded_files/SOFTWARE LICENSE AGREEMENT.docx", "rb")}

response = requests.post(url, files=files)
print(response.json())
# Out:
# {'detail': 'There was an error parsing the body'}
